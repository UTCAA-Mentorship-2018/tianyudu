# %%
import pandas as pd
import numpy as np
from scipy.stats import trim_mean, kurtosis
from scipy.stats.mstats import mode, gmean, hmean
from pprint import pprint

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn
import sklearn
from sklearn.ensemble.partial_dependence import plot_partial_dependence
from sklearn.ensemble.partial_dependence import partial_dependence
# Out:
# time: 153 ms

# %%
# ==== Customized Packages ====
import constants

# %%
# %load_ext autotime
pprint(constants.SAVED_FILE_DIRS)
# Out:
# {'CLOUD': 'https://s3.us-east-2.amazonaws.com/tianyudu/kaggle/application_train.csv',
#  'DRIVE': '/Volumes/Intel/Data/UTCAA-Mentorship-2018/application_train.csv',
#  'EC2': '/home/ec2-user/environment/mentor_2018/data/application_train.csv',
#  'EC2_server': '/home/ec2-user/data/application_train.csv',
#  'MAC': '/Users/tianyudu/Documents/Activities/UTCAA-Mentorship-2018/data/application_train.csv'}

# %%
df = pd.read_csv(constants.SAVED_FILE_DIRS["EC2_server"], sep=",", header="infer")
# Out:
# time: 4.54 s

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
X, y = df.drop(columns=["SK_ID_CURR", "TARGET"]), df["TARGET"]
# Out:
# time: 195 ms

# %%
print(f"Predictor Set: {X.shape}")
print(f"Response Set: {y.shape}")
# Out:
# Predictor Set: (307511, 120)
# Response Set: (307511,)
# time: 550 µs

# %%
df.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# ...

# %%
# Summary on y
plt.pie(
    [np.sum(y==0), np.sum(y==1)],
    labels=[f"Negative: {100*np.sum(y==0)/len(y):0.2f} %", 
            f"Positive: {100*np.sum(y==1)/len(y):0.2f} %"]
)
plt.show()
# Out:
# time: 106 ms

# %%
for col in df.columns: print(col)
# Out:
# SK_ID_CURR
# TARGET
# NAME_CONTRACT_TYPE
# CODE_GENDER
# FLAG_OWN_CAR
# FLAG_OWN_REALTY
# CNT_CHILDREN
# AMT_INCOME_TOTAL
# AMT_CREDIT
# AMT_ANNUITY
# AMT_GOODS_PRICE
# NAME_TYPE_SUITE
# NAME_INCOME_TYPE
# NAME_EDUCATION_TYPE
# NAME_FAMILY_STATUS
# NAME_HOUSING_TYPE
# REGION_POPULATION_RELATIVE
# DAYS_BIRTH
# DAYS_EMPLOYED
# DAYS_REGISTRATION
# DAYS_ID_PUBLISH
# OWN_CAR_AGE
# FLAG_MOBIL
# FLAG_EMP_PHONE
# FLAG_WORK_PHONE
# FLAG_CONT_MOBILE
# FLAG_PHONE
# FLAG_EMAIL
# OCCUPATION_TYPE
# CNT_FAM_MEMBERS
# REGION_RATING_CLIENT
# REGION_RATING_CLIENT_W_CITY
# WEEKDAY_APPR_PROCESS_START
# HOUR_APPR_PROCESS_START
# REG_REGION_NOT_LIVE_REGION
# REG_REGION_NOT_WORK_REGION
# LIVE_REGION_NOT_WORK_REGION
# REG_CITY_NOT_LIVE_CITY
# REG_CITY_NOT_WORK_CITY
# LIVE_CITY_NOT_WORK_CITY
# ORGANIZATION_TYPE
# EXT_SOURCE_1
# EXT_SOURCE_2
# EXT_SOURCE_3
# APARTMENTS_AVG
# BASEMENTAREA_AVG
# YEARS_BEGINEXPLUATATION_AVG
# YEARS_BUILD_AVG
# COMMONAREA_AVG
# ELEVATORS_AVG
# ENTRANCES_AVG
# FLOORSMAX_AVG
# ...

# %%
# Analyze feature correlation
var_corr = X.corr()
# Out:
# time: 12.4 s

# %%
seaborn.heatmap(var_corr)
plt.show()
# Out:
# time: 466 ms

# %%
# Manually select typical features
fea_set_1 = [
    "NAME_CONTRACT_TYPE",
    "CODE_GENDER",
    "FLAG_OWN_CAR",
    "FLAG_OWN_REALTY",
    "CNT_CHILDREN",
    "AMT_INCOME_TOTAL",
    "AMT_CREDIT",
    "AMT_ANNUITY",
    "AMT_GOODS_PRICE",
    "NAME_TYPE_SUITE",
    "NAME_INCOME_TYPE",
    "NAME_EDUCATION_TYPE",
    "NAME_FAMILY_STATUS",
    "NAME_HOUSING_TYPE",
    "REGION_POPULATION_RELATIVE",
    "DAYS_BIRTH"
]
len(fea_set_1)
# Out:
# 16
# time: 1.81 ms

# %%
sub_X = df[fea_set_1]
seaborn.heatmap(sub_X.corr())
plt.show()
# Out:
# time: 241 ms

# %%
from constants import *
from gbm_classifier_exec import *
# Out:
# Data set avaiable:
# {'CLOUD': 'https://s3.us-east-2.amazonaws.com/tianyudu/kaggle/application_train.csv',
#  'DRIVE': '/Volumes/Intel/Data/UTCAA-Mentorship-2018/application_train.csv',
#  'EC2': '/home/ec2-user/environment/mentor_2018/data/application_train.csv',
#  'EC2_server': '/home/ec2-user/data/application_train.csv',
#  'MAC': '/Users/tianyudu/Documents/Activities/UTCAA-Mentorship-2018/data/application_train.csv'}

# %%
# Partial Dependence
fig = plt.figure()
target_feature = y
pdp, axes = partial_dependence()
